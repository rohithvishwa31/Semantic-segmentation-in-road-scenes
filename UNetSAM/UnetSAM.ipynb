# %%
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
import glob
import numpy as np
import cv2
# Out:
# 2025-04-17 06:24:12.405546: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1744871052.606536      19 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1744871052.663734      19 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered

# %%
def spatial_attention(inputs):
    # Spatial Attention Branch (using Lambda layers)
    spatial_avg = Lambda(lambda x: tf.reduce_mean(x, axis=-1, keepdims=True))(inputs)
    spatial_max = Lambda(lambda x: tf.reduce_max(x, axis=-1, keepdims=True))(inputs)
    spatial = Concatenate()([spatial_avg, spatial_max])
    spatial = Conv2D(filters=1, kernel_size=7, padding='same', activation='sigmoid')(spatial)

    # Apply attention
    return Multiply()([inputs, spatial])

# %%
def unet_sam(input_shape=(256, 512, 3), num_classes=34):
    # Encoder (ResNet50 Backbone)
    base_model = tf.keras.applications.ResNet50(
        include_top=False,
        weights='imagenet',
        input_shape=input_shape
    )
    
    # Feature Extraction
    s1 = base_model.get_layer('conv1_relu').output       # 128x256
    s2 = base_model.get_layer('conv2_block3_out').output # 64x128
    s3 = base_model.get_layer('conv3_block4_out').output # 32x64
    s4 = base_model.get_layer('conv4_block6_out').output # 16x32

    # Decoder with Spatial Attention only
    d1 = UpSampling2D(2)(s4)  # 32x64
    d1 = concatenate([d1, s3])
    d1 = Conv2D(512, 3, padding='same', activation='relu')(d1)
    d1 = spatial_attention(d1)
    
    d2 = UpSampling2D(2)(d1)  # 64x128
    d2 = concatenate([d2, s2])
    d2 = Conv2D(256, 3, padding='same', activation='relu')(d2)
    d2 = spatial_attention(d2)
    
    d3 = UpSampling2D(2)(d2)  # 128x256
    d3 = concatenate([d3, s1])
    d3 = Conv2D(128, 3, padding='same', activation='relu')(d3)
    d3 = spatial_attention(d3)
    
    # Final Upsampling to Original Resolution
    d4 = UpSampling2D(2)(d3)  # 256x512
    outputs = Conv2D(num_classes, 1, activation='softmax')(d4)
    
    return Model(inputs=base_model.input, outputs=outputs)

# %%
# ======================================================
# Dataset Preparation
# ======================================================
def create_dataset(img_paths, label_paths, batch_size=8, shuffle=True):
    def process_path(img_path, label_path):
        img = tf.io.read_file(img_path)
        img = tf.image.decode_png(img, channels=3)
        img = tf.image.resize(img, (256, 512))
        img = tf.cast(img, tf.float32) / 127.5 - 1
        
        label = tf.io.read_file(label_path)
        label = tf.image.decode_png(label, channels=1)
        label = tf.image.resize(label, (256, 512), method='nearest')
        return img, label
    
    dataset = tf.data.Dataset.from_tensor_slices((img_paths, label_paths))
    dataset = dataset.map(process_path, num_parallel_calls=tf.data.AUTOTUNE)
    if shuffle:
        dataset = dataset.shuffle(1024)
    dataset = dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)
    return dataset

# %%
# Dataset preparation
img = glob.glob('../input/cityscapes/Cityspaces/images/train/*/*.png')
label = glob.glob('../input/cityscapes/Cityspaces/gtFine/train/*/*_gtFine_labelIds.png')

img = sorted(img)
label = sorted(label)

# Debug: Check dataset sizes
print(f"Number of images: {len(img)}")
print(f"Number of labels: {len(label)}")

# Create matching image-label pairs
paired = [(i, l) for i, l in zip(img, label) 
          if i.split('/')[-1].split('_leftImg8bit')[0] == l.split('/')[-1].split('_gtFine_labelIds')[0]]

img, label = zip(*paired)

img = list(img)
label = list(label)


# Create datasets
train_ds = create_dataset(img, label, shuffle=True)

# Dataset preparation
val_img = glob.glob('../input/cityscapes/Cityspaces/images/val/*/*.png')
val_label = glob.glob('../input/cityscapes/Cityspaces/gtFine/val/*/*_gtFine_labelIds.png')

val_img = sorted(val_img)
val_label = sorted(val_label)

# Debug: Check dataset sizes
print(f"Number of images: {len(val_img)}")
print(f"Number of labels: {len(val_label)}")

# Create matching image-label pairs
paired = [(i, l) for i, l in zip(img, label) 
          if i.split('/')[-1].split('_leftImg8bit')[0] == l.split('/')[-1].split('_gtFine_labelIds')[0]]

val_img, val_label = zip(*paired)

val_img = list(val_img)
val_label = list(val_label)


val_ds = create_dataset(val_img, val_label)

# Debug: Test dataset creation
for images, masks in train_ds.take(1):
    print("Train batch - Images shape:", images.shape)
    print("Train batch - Masks shape:", masks.shape)
# Out:
# Number of images: 2975
# Number of labels: 2975
# I0000 00:00:1744871068.343601      19 gpu_device.cc:2022] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 15513 MB memory:  -> device: 0, name: Tesla P100-PCIE-16GB, pci bus id: 0000:00:04.0, compute capability: 6.0
# Number of images: 500
# Number of labels: 500
# Train batch - Images shape: (8, 256, 512, 3)
# Train batch - Masks shape: (8, 256, 512, 1)

# %%
from tensorflow.keras.metrics import MeanIoU

# ======================================================
# Custom mIoU Metric with Argmax preprocessing
# ======================================================
class ArgmaxMeanIoU(MeanIoU):
    def __init__(self, num_classes, name='mean_iou', **kwargs):
        super().__init__(num_classes=num_classes, name=name, **kwargs)
    
    def update_state(self, y_true, y_pred, sample_weight=None):
        y_pred = tf.argmax(y_pred, axis=-1)
        return super().update_state(y_true, y_pred, sample_weight)

# ======================================================
# Model Compilation with Fixed Metrics
# ======================================================
model = unet_sam()
model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-4),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy', ArgmaxMeanIoU(num_classes=34)]
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Learning Rate Schedule
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.5, patience=3, verbose=1
)

# Training
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=50,
    callbacks=[lr_scheduler]
)
# Out:
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1744871166.012378      57 service.cc:148] XLA service 0x7c7f840032b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1744871166.013602      57 service.cc:156]   StreamExecutor device (0): Tesla P100-PCIE-16GB, Compute Capability 6.0
# W0000 00:00:1744871168.415215      57 assert_op.cc:38] Ignoring Assert operator compile_loss/sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/assert_equal_1/Assert/Assert
# I0000 00:00:1744871170.004945      57 cuda_dnn.cc:529] Loaded cuDNN version 90300
# I0000 00:00:1744871201.084535      57 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 371/372 ━━━━━━━━━━━━━━━━━━━━ 0s 261ms/step - accuracy: 0.7229 - loss: 1.1080 - mean_iou: 0.1533
# W0000 00:00:1744871299.605780      59 assert_op.cc:38] Ignoring Assert operator compile_loss/sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/assert_equal_1/Assert/Assert
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 0s 340ms/step - accuracy: 0.7231 - loss: 1.1069 - mean_iou: 0.1535
# W0000 00:00:1744871356.512063      58 assert_op.cc:38] Ignoring Assert operator compile_loss/sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/assert_equal_1/Assert/Assert
# W0000 00:00:1744871422.733951      58 assert_op.cc:38] Ignoring Assert operator compile_loss/sparse_categorical_crossentropy/SparseSoftmaxCrossEntropyWithLogits/assert_equal_1/Assert/Assert
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 328s 612ms/step - accuracy: 0.7233 - loss: 1.1059 - mean_iou: 0.1536 - val_accuracy: 0.5178 - val_loss: 1.9229 - val_mean_iou: 0.0501 - learning_rate: 1.0000e-04
# Epoch 2/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 236s 474ms/step - accuracy: 0.8599 - loss: 0.4556 - mean_iou: 0.3054 - val_accuracy: 0.7729 - val_loss: 0.7831 - val_mean_iou: 0.1857 - learning_rate: 1.0000e-04
# Epoch 3/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 201s 475ms/step - accuracy: 0.8797 - loss: 0.3746 - mean_iou: 0.3635 - val_accuracy: 0.8771 - val_loss: 0.3827 - val_mean_iou: 0.3787 - learning_rate: 1.0000e-04
# Epoch 4/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 201s 474ms/step - accuracy: 0.8901 - loss: 0.3331 - mean_iou: 0.4089 - val_accuracy: 0.8856 - val_loss: 0.3308 - val_mean_iou: 0.4348 - learning_rate: 1.0000e-04
# Epoch 5/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 201s 475ms/step - accuracy: 0.8980 - loss: 0.3035 - mean_iou: 0.4531 - val_accuracy: 0.9063 - val_loss: 0.2749 - val_mean_iou: 0.4632 - learning_rate: 1.0000e-04
# Epoch 6/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 200s 473ms/step - accuracy: 0.9061 - loss: 0.2753 - mean_iou: 0.4876 - val_accuracy: 0.9025 - val_loss: 0.2865 - val_mean_iou: 0.4860 - learning_rate: 1.0000e-04
# Epoch 7/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 201s 474ms/step - accuracy: 0.9136 - loss: 0.2485 - mean_iou: 0.5238 - val_accuracy: 0.9190 - val_loss: 0.2290 - val_mean_iou: 0.5900 - learning_rate: 1.0000e-04
# Epoch 8/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 199s 472ms/step - accuracy: 0.9185 - loss: 0.2312 - mean_iou: 0.5744 - val_accuracy: 0.9247 - val_loss: 0.2110 - val_mean_iou: 0.6099 - learning_rate: 1.0000e-04
# Epoch 9/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 200s 474ms/step - accuracy: 0.9231 - loss: 0.2149 - mean_iou: 0.6046 - val_accuracy: 0.9249 - val_loss: 0.2075 - val_mean_iou: 0.6271 - learning_rate: 1.0000e-04
# Epoch 10/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 200s 474ms/step - accuracy: 0.9259 - loss: 0.2046 - mean_iou: 0.6264 - val_accuracy: 0.9300 - val_loss: 0.1904 - val_mean_iou: 0.6452 - learning_rate: 1.0000e-04
# Epoch 11/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 201s 474ms/step - accuracy: 0.9277 - loss: 0.1980 - mean_iou: 0.6333 - val_accuracy: 0.9284 - val_loss: 0.1930 - val_mean_iou: 0.6503 - learning_rate: 1.0000e-04
# Epoch 12/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 200s 474ms/step - accuracy: 0.9258 - loss: 0.2034 - mean_iou: 0.6296 - val_accuracy: 0.9292 - val_loss: 0.1919 - val_mean_iou: 0.6511 - learning_rate: 1.0000e-04
# Epoch 13/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 203s 477ms/step - accuracy: 0.9329 - loss: 0.1797 - mean_iou: 0.6661 - val_accuracy: 0.9341 - val_loss: 0.1747 - val_mean_iou: 0.6807 - learning_rate: 1.0000e-04
# Epoch 14/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 201s 476ms/step - accuracy: 0.9361 - loss: 0.1684 - mean_iou: 0.6943 - val_accuracy: 0.9385 - val_loss: 0.1595 - val_mean_iou: 0.7076 - learning_rate: 1.0000e-04
# Epoch 15/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 201s 477ms/step - accuracy: 0.9380 - loss: 0.1615 - mean_iou: 0.7020 - val_accuracy: 0.9398 - val_loss: 0.1548 - val_mean_iou: 0.7155 - learning_rate: 1.0000e-04
# Epoch 16/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 200s 472ms/step - accuracy: 0.9392 - loss: 0.1570 - mean_iou: 0.7105 - val_accuracy: 0.9420 - val_loss: 0.1469 - val_mean_iou: 0.7263 - learning_rate: 1.0000e-04
# Epoch 17/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 200s 472ms/step - accuracy: 0.9359 - loss: 0.1686 - mean_iou: 0.6788 - val_accuracy: 0.9125 - val_loss: 0.2601 - val_mean_iou: 0.5590 - learning_rate: 1.0000e-04
# Epoch 18/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 201s 476ms/step - accuracy: 0.9294 - loss: 0.1901 - mean_iou: 0.6408 - val_accuracy: 0.9396 - val_loss: 0.1552 - val_mean_iou: 0.7073 - learning_rate: 1.0000e-04
# Epoch 19/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 0s 248ms/step - accuracy: 0.9388 - loss: 0.1576 - mean_iou: 0.6948
# Epoch 19: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 200s 474ms/step - accuracy: 0.9388 - loss: 0.1576 - mean_iou: 0.6949 - val_accuracy: 0.9399 - val_loss: 0.1535 - val_mean_iou: 0.7241 - learning_rate: 1.0000e-04
# Epoch 20/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 200s 473ms/step - accuracy: 0.9422 - loss: 0.1458 - mean_iou: 0.7277 - val_accuracy: 0.9473 - val_loss: 0.1290 - val_mean_iou: 0.7570 - learning_rate: 5.0000e-05
# Epoch 21/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 200s 474ms/step - accuracy: 0.9453 - loss: 0.1358 - mean_iou: 0.7491 - val_accuracy: 0.9487 - val_loss: 0.1243 - val_mean_iou: 0.7648 - learning_rate: 5.0000e-05
# Epoch 22/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 200s 473ms/step - accuracy: 0.9465 - loss: 0.1316 - mean_iou: 0.7512 - val_accuracy: 0.9497 - val_loss: 0.1208 - val_mean_iou: 0.7700 - learning_rate: 5.0000e-05
# Epoch 23/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 200s 474ms/step - accuracy: 0.9476 - loss: 0.1275 - mean_iou: 0.7569 - val_accuracy: 0.9496 - val_loss: 0.1212 - val_mean_iou: 0.7717 - learning_rate: 5.0000e-05
# Epoch 24/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 200s 475ms/step - accuracy: 0.9475 - loss: 0.1271 - mean_iou: 0.7619 - val_accuracy: 0.9504 - val_loss: 0.1180 - val_mean_iou: 0.7749 - learning_rate: 5.0000e-05
# Epoch 25/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 201s 473ms/step - accuracy: 0.9482 - loss: 0.1249 - mean_iou: 0.7717 - val_accuracy: 0.9502 - val_loss: 0.1181 - val_mean_iou: 0.7753 - learning_rate: 5.0000e-05
# Epoch 26/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 200s 472ms/step - accuracy: 0.9488 - loss: 0.1229 - mean_iou: 0.7708 - val_accuracy: 0.9510 - val_loss: 0.1153 - val_mean_iou: 0.7790 - learning_rate: 5.0000e-05
# Epoch 27/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 201s 476ms/step - accuracy: 0.9492 - loss: 0.1214 - mean_iou: 0.7656 - val_accuracy: 0.9516 - val_loss: 0.1135 - val_mean_iou: 0.7802 - learning_rate: 5.0000e-05
# Epoch 28/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 200s 474ms/step - accuracy: 0.9495 - loss: 0.1198 - mean_iou: 0.7799 - val_accuracy: 0.9520 - val_loss: 0.1119 - val_mean_iou: 0.7858 - learning_rate: 5.0000e-05
# Epoch 29/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 200s 473ms/step - accuracy: 0.9504 - loss: 0.1172 - mean_iou: 0.7796 - val_accuracy: 0.9526 - val_loss: 0.1098 - val_mean_iou: 0.7866 - learning_rate: 5.0000e-05
# Epoch 30/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 200s 473ms/step - accuracy: 0.9512 - loss: 0.1145 - mean_iou: 0.7836 - val_accuracy: 0.9530 - val_loss: 0.1082 - val_mean_iou: 0.7883 - learning_rate: 5.0000e-05
# Epoch 31/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 200s 473ms/step - accuracy: 0.9515 - loss: 0.1131 - mean_iou: 0.7851 - val_accuracy: 0.9532 - val_loss: 0.1076 - val_mean_iou: 0.7921 - learning_rate: 5.0000e-05
# Epoch 32/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 201s 473ms/step - accuracy: 0.9520 - loss: 0.1116 - mean_iou: 0.7835 - val_accuracy: 0.9538 - val_loss: 0.1056 - val_mean_iou: 0.7949 - learning_rate: 5.0000e-05
# Epoch 33/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 199s 472ms/step - accuracy: 0.9524 - loss: 0.1102 - mean_iou: 0.7757 - val_accuracy: 0.9544 - val_loss: 0.1032 - val_mean_iou: 0.7984 - learning_rate: 5.0000e-05
# Epoch 34/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 201s 476ms/step - accuracy: 0.9528 - loss: 0.1084 - mean_iou: 0.7908 - val_accuracy: 0.9549 - val_loss: 0.1018 - val_mean_iou: 0.7975 - learning_rate: 5.0000e-05
# Epoch 35/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 201s 475ms/step - accuracy: 0.9535 - loss: 0.1064 - mean_iou: 0.7894 - val_accuracy: 0.9551 - val_loss: 0.1009 - val_mean_iou: 0.7981 - learning_rate: 5.0000e-05
# Epoch 36/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 201s 474ms/step - accuracy: 0.9538 - loss: 0.1052 - mean_iou: 0.7920 - val_accuracy: 0.9556 - val_loss: 0.0993 - val_mean_iou: 0.8010 - learning_rate: 5.0000e-05
# Epoch 37/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 201s 477ms/step - accuracy: 0.9543 - loss: 0.1037 - mean_iou: 0.7969 - val_accuracy: 0.9558 - val_loss: 0.0985 - val_mean_iou: 0.8054 - learning_rate: 5.0000e-05
# Epoch 38/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 201s 475ms/step - accuracy: 0.9546 - loss: 0.1025 - mean_iou: 0.7980 - val_accuracy: 0.9563 - val_loss: 0.0968 - val_mean_iou: 0.8055 - learning_rate: 5.0000e-05
# Epoch 39/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 201s 476ms/step - accuracy: 0.9550 - loss: 0.1011 - mean_iou: 0.7974 - val_accuracy: 0.9567 - val_loss: 0.0957 - val_mean_iou: 0.8083 - learning_rate: 5.0000e-05
# Epoch 40/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 201s 474ms/step - accuracy: 0.9553 - loss: 0.1001 - mean_iou: 0.8049 - val_accuracy: 0.9569 - val_loss: 0.0948 - val_mean_iou: 0.8118 - learning_rate: 5.0000e-05
# Epoch 41/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 202s 476ms/step - accuracy: 0.9554 - loss: 0.0996 - mean_iou: 0.8026 - val_accuracy: 0.9569 - val_loss: 0.0948 - val_mean_iou: 0.8086 - learning_rate: 5.0000e-05
# Epoch 42/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 201s 475ms/step - accuracy: 0.9557 - loss: 0.0986 - mean_iou: 0.8065 - val_accuracy: 0.9572 - val_loss: 0.0935 - val_mean_iou: 0.8106 - learning_rate: 5.0000e-05
# Epoch 43/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 201s 475ms/step - accuracy: 0.9562 - loss: 0.0971 - mean_iou: 0.8053 - val_accuracy: 0.9576 - val_loss: 0.0926 - val_mean_iou: 0.8150 - learning_rate: 5.0000e-05
# Epoch 44/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 200s 474ms/step - accuracy: 0.9565 - loss: 0.0961 - mean_iou: 0.8116 - val_accuracy: 0.9579 - val_loss: 0.0914 - val_mean_iou: 0.8167 - learning_rate: 5.0000e-05
# Epoch 45/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 201s 476ms/step - accuracy: 0.9565 - loss: 0.0956 - mean_iou: 0.8130 - val_accuracy: 0.9583 - val_loss: 0.0903 - val_mean_iou: 0.8185 - learning_rate: 5.0000e-05
# Epoch 46/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 201s 476ms/step - accuracy: 0.9572 - loss: 0.0936 - mean_iou: 0.8145 - val_accuracy: 0.9585 - val_loss: 0.0893 - val_mean_iou: 0.8208 - learning_rate: 5.0000e-05
# Epoch 47/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 201s 476ms/step - accuracy: 0.9570 - loss: 0.0940 - mean_iou: 0.8153 - val_accuracy: 0.9584 - val_loss: 0.0898 - val_mean_iou: 0.8207 - learning_rate: 5.0000e-05
# Epoch 48/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 201s 474ms/step - accuracy: 0.9575 - loss: 0.0924 - mean_iou: 0.8046 - val_accuracy: 0.9586 - val_loss: 0.0890 - val_mean_iou: 0.8233 - learning_rate: 5.0000e-05
# Epoch 49/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 200s 473ms/step - accuracy: 0.9577 - loss: 0.0917 - mean_iou: 0.8158 - val_accuracy: 0.9591 - val_loss: 0.0873 - val_mean_iou: 0.8231 - learning_rate: 5.0000e-05
# Epoch 50/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 201s 476ms/step - accuracy: 0.9579 - loss: 0.0911 - mean_iou: 0.8172 - val_accuracy: 0.9586 - val_loss: 0.0886 - val_mean_iou: 0.8247 - learning_rate: 5.0000e-05

# %%
model.save('cityscapes_unet_sam.keras')

# %%
import matplotlib.pyplot as plt
# ======================================================
# Prediction
# ======================================================
def visualize_prediction(image_path):
    img = cv2.imread(image_path)
    original = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    resized = cv2.resize(original, (512, 256))
    normalized = (resized / 127.5) - 1.0
    
    pred = model.predict(tf.expand_dims(normalized, 0))
    pred_mask = tf.argmax(pred[0], axis=-1).numpy().astype(np.uint8)
    
    plt.figure(figsize=(12, 6))
    plt.subplot(121); plt.imshow(resized)
    plt.subplot(122); plt.imshow(pred_mask)
    plt.show()

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    # Create subplots
    plt.figure(figsize=(15, 5))
    
    # Plot Loss
    plt.subplot(1, 3, 1)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    
    # Plot Accuracy
    plt.subplot(1, 3, 2)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Val Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)
    
    # Plot mIoU
    plt.subplot(1, 3, 3)
    plt.plot(history.history['mean_iou'], label='Train mIoU')
    plt.plot(history.history['val_mean_iou'], label='Val mIoU')
    plt.title('Training and Validation mIoU')
    plt.xlabel('Epochs')
    plt.ylabel('mIoU')
    plt.legend()
    plt.grid(True)

# %%
visualize_prediction("/kaggle/input/cityscapes/Cityspaces/images/val/lindau/lindau_000009_000019_leftImg8bit.png")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step

# %%
def plot_training_history(history):
    # Create subplots
    plt.figure(figsize=(15, 5))
    
    # Plot Loss
    plt.subplot(1, 3, 1)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    
    # Plot Accuracy
    plt.subplot(1, 3, 2)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Val Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)
    
    # Plot mIoU
    plt.subplot(1, 3, 3)
    plt.plot(history.history['mean_iou'], label='Train mIoU')
    plt.plot(history.history['val_mean_iou'], label='Val mIoU')
    plt.title('Training and Validation mIoU')
    plt.xlabel('Epochs')
    plt.ylabel('mIoU')
    plt.legend()
    plt.grid(True)

    plt.tight_layout()
    plt.show()

# After training, call the function with your history object
plot_training_history(history)
