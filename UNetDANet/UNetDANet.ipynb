# %%
import tensorflow as tf
from tensorflow.keras.layers import *
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import Adam
import glob
import numpy as np
import cv2

# %%
# ======================================================
# Revised Dual Attention Module with Keras-compatible ops
# ======================================================
def dual_attention(inputs):
    # Channel Attention Branch
    channel_avg = GlobalAveragePooling2D(keepdims=True)(inputs)
    channel_avg = Conv2D(filters=inputs.shape[-1]//8, 
                        kernel_size=1, 
                        activation='relu')(channel_avg)
    channel_avg = Conv2D(filters=inputs.shape[-1], 
                        kernel_size=1, 
                        activation='sigmoid')(channel_avg)

    # Spatial Attention Branch (using Lambda layers)
    spatial_avg = Lambda(lambda x: tf.reduce_mean(x, axis=-1, keepdims=True))(inputs)
    spatial_max = Lambda(lambda x: tf.reduce_max(x, axis=-1, keepdims=True))(inputs)
    spatial = Concatenate()([spatial_avg, spatial_max])
    spatial = Conv2D(filters=1, 
                    kernel_size=7, 
                    padding='same', 
                    activation='sigmoid')(spatial)

    # Combined Attention
    attention = Multiply()([channel_avg, spatial])
    return Multiply()([inputs, attention])

# %%
def unet_da(input_shape=(256, 512, 3), num_classes=34):
    # Encoder (ResNet50 Backbone)
    base_model = tf.keras.applications.ResNet50(
        include_top=False,
        weights='imagenet',
        input_shape=input_shape
    )
    
    # Feature Extraction
    s1 = base_model.get_layer('conv1_relu').output       # 128x256
    s2 = base_model.get_layer('conv2_block3_out').output # 64x128
    s3 = base_model.get_layer('conv3_block4_out').output # 32x64
    s4 = base_model.get_layer('conv4_block6_out').output # 16x32

    # Decoder with Additional Upsampling
    d1 = UpSampling2D(2)(s4)  # 32x64
    d1 = concatenate([d1, s3])
    d1 = Conv2D(512, 3, padding='same', activation='relu')(d1)
    d1 = dual_attention(d1)
    
    d2 = UpSampling2D(2)(d1)  # 64x128
    d2 = concatenate([d2, s2])
    d2 = Conv2D(256, 3, padding='same', activation='relu')(d2)
    d2 = dual_attention(d2)
    
    d3 = UpSampling2D(2)(d2)  # 128x256
    d3 = concatenate([d3, s1])
    d3 = Conv2D(128, 3, padding='same', activation='relu')(d3)
    d3 = dual_attention(d3)
    
    # Final Upsampling to Original Resolution
    d4 = UpSampling2D(2)(d3)  # 256x512
    outputs = Conv2D(num_classes, 1, activation='softmax')(d4)
    
    return Model(inputs=base_model.input, outputs=outputs)

# %%
# ======================================================
# Dataset Preparation
# ======================================================
def create_dataset(img_paths, label_paths, batch_size=8, shuffle=True):
    def process_path(img_path, label_path):
        img = tf.io.read_file(img_path)
        img = tf.image.decode_png(img, channels=3)
        img = tf.image.resize(img, (256, 512))
        img = tf.cast(img, tf.float32) / 127.5 - 1
        
        label = tf.io.read_file(label_path)
        label = tf.image.decode_png(label, channels=1)
        label = tf.image.resize(label, (256, 512), method='nearest')
        return img, label
    
    dataset = tf.data.Dataset.from_tensor_slices((img_paths, label_paths))
    dataset = dataset.map(process_path, num_parallel_calls=tf.data.AUTOTUNE)
    if shuffle:
        dataset = dataset.shuffle(1024)
    dataset = dataset.batch(batch_size).prefetch(tf.data.AUTOTUNE)
    return dataset

# %%
# Dataset preparation
img = glob.glob('../input/cityscapes/Cityspaces/images/train/*/*.png')
label = glob.glob('../input/cityscapes/Cityspaces/gtFine/train/*/*_gtFine_labelIds.png')

img = sorted(img)
label = sorted(label)

# Debug: Check dataset sizes
print(f"Number of images: {len(img)}")
print(f"Number of labels: {len(label)}")

# Create matching image-label pairs
paired = [(i, l) for i, l in zip(img, label) 
          if i.split('/')[-1].split('_leftImg8bit')[0] == l.split('/')[-1].split('_gtFine_labelIds')[0]]

img, label = zip(*paired)

img = list(img)
label = list(label)


# Create datasets
train_ds = create_dataset(img, label, shuffle=True)

# Dataset preparation
val_img = glob.glob('../input/cityscapes/Cityspaces/images/val/*/*.png')
val_label = glob.glob('../input/cityscapes/Cityspaces/gtFine/val/*/*_gtFine_labelIds.png')

val_img = sorted(val_img)
val_label = sorted(val_label)

# Debug: Check dataset sizes
print(f"Number of images: {len(val_img)}")
print(f"Number of labels: {len(val_label)}")

# Create matching image-label pairs
paired = [(i, l) for i, l in zip(img, label) 
          if i.split('/')[-1].split('_leftImg8bit')[0] == l.split('/')[-1].split('_gtFine_labelIds')[0]]

val_img, val_label = zip(*paired)

val_img = list(val_img)
val_label = list(val_label)


val_ds = create_dataset(val_img, val_label)

# Debug: Test dataset creation
for images, masks in train_ds.take(1):
    print("Train batch - Images shape:", images.shape)
    print("Train batch - Masks shape:", masks.shape)
# Out:
# Number of images: 2975
# Number of labels: 2975
# Number of images: 500
# Number of labels: 500
# Train batch - Images shape: (8, 256, 512, 3)
# Train batch - Masks shape: (8, 256, 512, 1)

# %%
from tensorflow.keras.metrics import MeanIoU

# ======================================================
# Custom mIoU Metric with Argmax preprocessing
# ======================================================
class ArgmaxMeanIoU(MeanIoU):
    def __init__(self, num_classes, name='mean_iou', **kwargs):
        super().__init__(num_classes=num_classes, name=name, **kwargs)
    
    def update_state(self, y_true, y_pred, sample_weight=None):
        y_pred = tf.argmax(y_pred, axis=-1)
        return super().update_state(y_true, y_pred, sample_weight)

# ======================================================
# Model Compilation with Fixed Metrics
# ======================================================
model = unet_da()
model.compile(
    optimizer=tf.keras.optimizers.Adam(1e-4),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy', ArgmaxMeanIoU(num_classes=34)]
)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet/resnet50_weights_tf_dim_ordering_tf_kernels_notop.h5
# 94765736/94765736 ━━━━━━━━━━━━━━━━━━━━ 3s 0us/step

# %%
# Learning Rate Schedule
lr_scheduler = tf.keras.callbacks.ReduceLROnPlateau(
    monitor='val_loss', factor=0.5, patience=3, verbose=1
)

# Training
history = model.fit(
    train_ds,
    validation_data=val_ds,
    epochs=50,
    callbacks=[lr_scheduler]
)
# Out:
# Epoch 1/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 346s 681ms/step - accuracy: 0.5344 - loss: 1.9968 - mean_iou: 0.0824 - val_accuracy: 0.5326 - val_loss: 2.3051 - val_mean_iou: 0.0411 - learning_rate: 1.0000e-04
# Epoch 2/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 225s 528ms/step - accuracy: 0.8551 - loss: 0.4881 - mean_iou: 0.2709 - val_accuracy: 0.7971 - val_loss: 0.7176 - val_mean_iou: 0.2052 - learning_rate: 1.0000e-04
# Epoch 3/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 225s 528ms/step - accuracy: 0.8762 - loss: 0.3878 - mean_iou: 0.3413 - val_accuracy: 0.8792 - val_loss: 0.3764 - val_mean_iou: 0.3486 - learning_rate: 1.0000e-04
# Epoch 4/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 226s 530ms/step - accuracy: 0.8857 - loss: 0.3513 - mean_iou: 0.3845 - val_accuracy: 0.8921 - val_loss: 0.3274 - val_mean_iou: 0.4015 - learning_rate: 1.0000e-04
# Epoch 5/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 226s 530ms/step - accuracy: 0.8976 - loss: 0.3074 - mean_iou: 0.4275 - val_accuracy: 0.9050 - val_loss: 0.2782 - val_mean_iou: 0.4473 - learning_rate: 1.0000e-04
# Epoch 6/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 225s 529ms/step - accuracy: 0.9044 - loss: 0.2810 - mean_iou: 0.4702 - val_accuracy: 0.9102 - val_loss: 0.2609 - val_mean_iou: 0.4846 - learning_rate: 1.0000e-04
# Epoch 7/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 262s 529ms/step - accuracy: 0.9106 - loss: 0.2603 - mean_iou: 0.5013 - val_accuracy: 0.9134 - val_loss: 0.2507 - val_mean_iou: 0.5311 - learning_rate: 1.0000e-04
# Epoch 8/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 227s 532ms/step - accuracy: 0.9167 - loss: 0.2395 - mean_iou: 0.5244 - val_accuracy: 0.9210 - val_loss: 0.2255 - val_mean_iou: 0.5569 - learning_rate: 1.0000e-04
# Epoch 9/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 226s 530ms/step - accuracy: 0.9204 - loss: 0.2252 - mean_iou: 0.5541 - val_accuracy: 0.9235 - val_loss: 0.2149 - val_mean_iou: 0.5692 - learning_rate: 1.0000e-04
# Epoch 10/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 227s 533ms/step - accuracy: 0.9219 - loss: 0.2196 - mean_iou: 0.5741 - val_accuracy: 0.9278 - val_loss: 0.1994 - val_mean_iou: 0.5984 - learning_rate: 1.0000e-04
# Epoch 11/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 260s 529ms/step - accuracy: 0.9262 - loss: 0.2049 - mean_iou: 0.6014 - val_accuracy: 0.9320 - val_loss: 0.1843 - val_mean_iou: 0.6387 - learning_rate: 1.0000e-04
# Epoch 12/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 227s 534ms/step - accuracy: 0.9300 - loss: 0.1915 - mean_iou: 0.6331 - val_accuracy: 0.9265 - val_loss: 0.2018 - val_mean_iou: 0.6366 - learning_rate: 1.0000e-04
# Epoch 13/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 229s 538ms/step - accuracy: 0.9323 - loss: 0.1826 - mean_iou: 0.6485 - val_accuracy: 0.9346 - val_loss: 0.1738 - val_mean_iou: 0.6766 - learning_rate: 1.0000e-04
# Epoch 14/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 227s 532ms/step - accuracy: 0.9333 - loss: 0.1787 - mean_iou: 0.6613 - val_accuracy: 0.9363 - val_loss: 0.1678 - val_mean_iou: 0.6841 - learning_rate: 1.0000e-04
# Epoch 15/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 228s 534ms/step - accuracy: 0.9351 - loss: 0.1718 - mean_iou: 0.6841 - val_accuracy: 0.9385 - val_loss: 0.1604 - val_mean_iou: 0.7041 - learning_rate: 1.0000e-04
# Epoch 16/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 227s 533ms/step - accuracy: 0.9382 - loss: 0.1615 - mean_iou: 0.6981 - val_accuracy: 0.9398 - val_loss: 0.1552 - val_mean_iou: 0.7075 - learning_rate: 1.0000e-04
# Epoch 17/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 227s 532ms/step - accuracy: 0.9389 - loss: 0.1587 - mean_iou: 0.6948 - val_accuracy: 0.9111 - val_loss: 0.2646 - val_mean_iou: 0.5817 - learning_rate: 1.0000e-04
# Epoch 18/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 223s 524ms/step - accuracy: 0.9242 - loss: 0.2081 - mean_iou: 0.6083 - val_accuracy: 0.9336 - val_loss: 0.1764 - val_mean_iou: 0.6721 - learning_rate: 1.0000e-04
# Epoch 19/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 223s 524ms/step - accuracy: 0.9374 - loss: 0.1631 - mean_iou: 0.6785 - val_accuracy: 0.9430 - val_loss: 0.1441 - val_mean_iou: 0.7304 - learning_rate: 1.0000e-04
# Epoch 20/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 225s 529ms/step - accuracy: 0.9416 - loss: 0.1488 - mean_iou: 0.7255 - val_accuracy: 0.9450 - val_loss: 0.1374 - val_mean_iou: 0.7359 - learning_rate: 1.0000e-04
# Epoch 21/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 225s 529ms/step - accuracy: 0.9432 - loss: 0.1432 - mean_iou: 0.7382 - val_accuracy: 0.9462 - val_loss: 0.1330 - val_mean_iou: 0.7489 - learning_rate: 1.0000e-04
# Epoch 22/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 226s 531ms/step - accuracy: 0.9451 - loss: 0.1367 - mean_iou: 0.7424 - val_accuracy: 0.9469 - val_loss: 0.1302 - val_mean_iou: 0.7480 - learning_rate: 1.0000e-04
# Epoch 23/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 225s 528ms/step - accuracy: 0.9449 - loss: 0.1369 - mean_iou: 0.7459 - val_accuracy: 0.9468 - val_loss: 0.1306 - val_mean_iou: 0.7521 - learning_rate: 1.0000e-04
# Epoch 24/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 225s 529ms/step - accuracy: 0.9457 - loss: 0.1338 - mean_iou: 0.7380 - val_accuracy: 0.9467 - val_loss: 0.1301 - val_mean_iou: 0.7518 - learning_rate: 1.0000e-04
# Epoch 25/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 225s 528ms/step - accuracy: 0.9461 - loss: 0.1321 - mean_iou: 0.7515 - val_accuracy: 0.9468 - val_loss: 0.1296 - val_mean_iou: 0.7527 - learning_rate: 1.0000e-04
# Epoch 26/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 225s 529ms/step - accuracy: 0.9466 - loss: 0.1305 - mean_iou: 0.7447 - val_accuracy: 0.9314 - val_loss: 0.1831 - val_mean_iou: 0.6666 - learning_rate: 1.0000e-04
# Epoch 27/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 225s 528ms/step - accuracy: 0.9263 - loss: 0.2011 - mean_iou: 0.6315 - val_accuracy: 0.9000 - val_loss: 0.2910 - val_mean_iou: 0.5694 - learning_rate: 1.0000e-04
# Epoch 28/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 0s 266ms/step - accuracy: 0.9398 - loss: 0.1537 - mean_iou: 0.7013
# Epoch 28: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-05.
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 225s 528ms/step - accuracy: 0.9398 - loss: 0.1537 - mean_iou: 0.7014 - val_accuracy: 0.9452 - val_loss: 0.1349 - val_mean_iou: 0.7463 - learning_rate: 1.0000e-04
# Epoch 29/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 225s 527ms/step - accuracy: 0.9471 - loss: 0.1286 - mean_iou: 0.7522 - val_accuracy: 0.9516 - val_loss: 0.1142 - val_mean_iou: 0.7821 - learning_rate: 5.0000e-05
# Epoch 30/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 225s 527ms/step - accuracy: 0.9497 - loss: 0.1202 - mean_iou: 0.7701 - val_accuracy: 0.9529 - val_loss: 0.1098 - val_mean_iou: 0.7876 - learning_rate: 5.0000e-05
# Epoch 31/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 225s 530ms/step - accuracy: 0.9512 - loss: 0.1152 - mean_iou: 0.7740 - val_accuracy: 0.9536 - val_loss: 0.1073 - val_mean_iou: 0.7917 - learning_rate: 5.0000e-05
# Epoch 32/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 225s 530ms/step - accuracy: 0.9514 - loss: 0.1143 - mean_iou: 0.7829 - val_accuracy: 0.9539 - val_loss: 0.1058 - val_mean_iou: 0.7937 - learning_rate: 5.0000e-05
# Epoch 33/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 225s 528ms/step - accuracy: 0.9523 - loss: 0.1112 - mean_iou: 0.7874 - val_accuracy: 0.9542 - val_loss: 0.1048 - val_mean_iou: 0.7957 - learning_rate: 5.0000e-05
# Epoch 34/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 226s 530ms/step - accuracy: 0.9527 - loss: 0.1095 - mean_iou: 0.7862 - val_accuracy: 0.9545 - val_loss: 0.1035 - val_mean_iou: 0.7981 - learning_rate: 5.0000e-05
# Epoch 35/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 226s 530ms/step - accuracy: 0.9527 - loss: 0.1093 - mean_iou: 0.7931 - val_accuracy: 0.9546 - val_loss: 0.1030 - val_mean_iou: 0.7950 - learning_rate: 5.0000e-05
# Epoch 36/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 226s 530ms/step - accuracy: 0.9529 - loss: 0.1085 - mean_iou: 0.7933 - val_accuracy: 0.9546 - val_loss: 0.1034 - val_mean_iou: 0.7947 - learning_rate: 5.0000e-05
# Epoch 37/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 225s 529ms/step - accuracy: 0.9533 - loss: 0.1071 - mean_iou: 0.7804 - val_accuracy: 0.9552 - val_loss: 0.1011 - val_mean_iou: 0.7983 - learning_rate: 5.0000e-05
# Epoch 38/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 262s 528ms/step - accuracy: 0.9534 - loss: 0.1064 - mean_iou: 0.7889 - val_accuracy: 0.9555 - val_loss: 0.0997 - val_mean_iou: 0.8035 - learning_rate: 5.0000e-05
# Epoch 39/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 226s 531ms/step - accuracy: 0.9541 - loss: 0.1044 - mean_iou: 0.7894 - val_accuracy: 0.9558 - val_loss: 0.0989 - val_mean_iou: 0.8045 - learning_rate: 5.0000e-05
# Epoch 40/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 225s 528ms/step - accuracy: 0.9541 - loss: 0.1040 - mean_iou: 0.7956 - val_accuracy: 0.9561 - val_loss: 0.0980 - val_mean_iou: 0.8066 - learning_rate: 5.0000e-05
# Epoch 41/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 225s 528ms/step - accuracy: 0.9545 - loss: 0.1026 - mean_iou: 0.7903 - val_accuracy: 0.9566 - val_loss: 0.0961 - val_mean_iou: 0.8085 - learning_rate: 5.0000e-05
# Epoch 42/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 225s 528ms/step - accuracy: 0.9551 - loss: 0.1008 - mean_iou: 0.8033 - val_accuracy: 0.9567 - val_loss: 0.0954 - val_mean_iou: 0.8086 - learning_rate: 5.0000e-05
# Epoch 43/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 225s 527ms/step - accuracy: 0.9554 - loss: 0.0997 - mean_iou: 0.8029 - val_accuracy: 0.9569 - val_loss: 0.0950 - val_mean_iou: 0.8082 - learning_rate: 5.0000e-05
# Epoch 44/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 225s 529ms/step - accuracy: 0.9558 - loss: 0.0984 - mean_iou: 0.8001 - val_accuracy: 0.9572 - val_loss: 0.0939 - val_mean_iou: 0.8104 - learning_rate: 5.0000e-05
# Epoch 45/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 225s 528ms/step - accuracy: 0.9560 - loss: 0.0976 - mean_iou: 0.8087 - val_accuracy: 0.9575 - val_loss: 0.0929 - val_mean_iou: 0.8131 - learning_rate: 5.0000e-05
# Epoch 46/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 225s 528ms/step - accuracy: 0.9561 - loss: 0.0970 - mean_iou: 0.8105 - val_accuracy: 0.9578 - val_loss: 0.0919 - val_mean_iou: 0.8157 - learning_rate: 5.0000e-05
# Epoch 47/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 225s 530ms/step - accuracy: 0.9564 - loss: 0.0963 - mean_iou: 0.8102 - val_accuracy: 0.9580 - val_loss: 0.0910 - val_mean_iou: 0.8171 - learning_rate: 5.0000e-05
# Epoch 48/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 226s 529ms/step - accuracy: 0.9567 - loss: 0.0952 - mean_iou: 0.8111 - val_accuracy: 0.9582 - val_loss: 0.0904 - val_mean_iou: 0.8167 - learning_rate: 5.0000e-05
# Epoch 49/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 225s 530ms/step - accuracy: 0.9570 - loss: 0.0942 - mean_iou: 0.8046 - val_accuracy: 0.9583 - val_loss: 0.0900 - val_mean_iou: 0.8180 - learning_rate: 5.0000e-05
# Epoch 50/50
# 372/372 ━━━━━━━━━━━━━━━━━━━━ 225s 529ms/step - accuracy: 0.9567 - loss: 0.0948 - mean_iou: 0.8134 - val_accuracy: 0.9589 - val_loss: 0.0882 - val_mean_iou: 0.8199 - learning_rate: 5.0000e-05

# %%
model.save('cityscapes_unet_da.keras')

# %%
import matplotlib.pyplot as plt
# ======================================================
# Prediction
# ======================================================
def visualize_prediction(image_path):
    img = cv2.imread(image_path)
    original = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
    resized = cv2.resize(original, (512, 256))
    normalized = (resized / 127.5) - 1.0
    
    pred = model.predict(tf.expand_dims(normalized, 0))
    pred_mask = tf.argmax(pred[0], axis=-1).numpy().astype(np.uint8)
    
    plt.figure(figsize=(12, 6))
    plt.subplot(121); plt.imshow(resized)
    plt.subplot(122); plt.imshow(pred_mask)
    plt.show()

# %%
visualize_prediction("/kaggle/input/cityscapes/Cityspaces/images/val/lindau/lindau_000009_000019_leftImg8bit.png")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step

# %%
import matplotlib.pyplot as plt

def plot_training_history(history):
    # Create subplots
    plt.figure(figsize=(15, 5))
    
    # Plot Loss
    plt.subplot(1, 3, 1)
    plt.plot(history.history['loss'], label='Train Loss')
    plt.plot(history.history['val_loss'], label='Val Loss')
    plt.title('Training and Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.grid(True)
    
    # Plot Accuracy
    plt.subplot(1, 3, 2)
    plt.plot(history.history['accuracy'], label='Train Accuracy')
    plt.plot(history.history['val_accuracy'], label='Val Accuracy')
    plt.title('Training and Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.grid(True)
    
    # Plot mIoU
    plt.subplot(1, 3, 3)
    plt.plot(history.history['mean_iou'], label='Train mIoU')
    plt.plot(history.history['val_mean_iou'], label='Val mIoU')
    plt.title('Training and Validation mIoU')
    plt.xlabel('Epochs')
    plt.ylabel('mIoU')
    plt.legend()
    plt.grid(True)
    
    plt.tight_layout()
    plt.show()

# After training, call the function with your history object
plot_training_history(history)
